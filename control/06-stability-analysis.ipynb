# %% [markdown]
# **Problem 6**: While poles determine system behaviour, practical systems often have many poles, making direct analysis difficult. How can we determine whether a system is stable, identify the poles that dominate its behaviour, and predict how controller gains move those poles without repeatedly solving high-order characteristic equations?
